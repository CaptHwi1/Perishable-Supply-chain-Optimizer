# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 869D-5697
#
#  Directory of C:\Users\user\Desktop\Library\Work\PROJECTS\Perishable Supply chain Optimizer\Archive
#
# 12/03/2025  02:21 PM    <DIR>          .
# 12/03/2025  02:14 PM    <DIR>          ..
# 12/03/2025  02:21 PM    <DIR>          .ipynb_checkpoints
# 12/03/2025  11:10 AM            40,698 main.py
# 12/03/2025  02:21 PM                 0 main_v1.py
# 12/03/2025  11:28 AM            40,982 main_v2.py
# 12/03/2025  11:41 AM            40,972 main_v3.py
# 12/03/2025  12:03 PM            44,212 main_v4.py
# 12/03/2025  12:22 PM            47,010 main_v5.py
# 12/03/2025  12:37 PM            47,000 main_v6.py
# 12/03/2025  02:19 PM             4,051 Test.ipynb
#                8 File(s)        264,925 bytes
#                3 Dir(s)  39,129,378,816 bytes free

# %%
# !python main_v1.py
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\Lib\tkinter\__init__.py", line 2068, in __call__
#     return self.func(*args)
#            ~~~~~~~~~^^^^^^^
#   File "C:\Users\user\Desktop\Library\Work\PROJECTS\Perishable Supply chain Optimizer\Archive\main_v1.py", line 554, in add_product
#     self.update_ui()
#     ~~~~~~~~~~~~~~^^
#   File "C:\Users\user\Desktop\Library\Work\PROJECTS\Perishable Supply chain Optimizer\Archive\main_v1.py", line 535, in update_ui
#     cb.grid(row=i//5 + 1, column=i%5, sticky="w", padx=5, pady=2)
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\Lib\tkinter\__init__.py", line 2693, in grid_configure
#     self.tk.call(
#     ~~~~~~~~~~~~^
#           ('grid', 'configure', self._w)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#           + self._options(cnf, kw))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
