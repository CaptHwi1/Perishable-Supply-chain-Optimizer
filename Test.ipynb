# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 869D-5697
#
#  Directory of C:\Users\user\Desktop\Library\Work\PROJECTS\Perishable Supply chain Optimizer
#
# 12/03/2025  04:34 PM    <DIR>          .
# 12/03/2025  03:40 PM    <DIR>          ..
# 12/03/2025  04:26 PM    <DIR>          .ipynb_checkpoints
# 12/03/2025  10:15 AM           922,612 App-icon.png
# 12/03/2025  04:26 PM    <DIR>          Archive
# 12/03/2025  04:34 PM            47,497 main_v02.py
# 12/03/2025  04:20 PM            80,419 Test.ipynb
#                3 File(s)      1,050,528 bytes
#                4 Dir(s)  38,309,408,768 bytes free

# %%
# !python main_v02.py

# %%
# !pyinstaller --onefile --windowed  --icon="App-icon.png" --name "Perishable SC Optimizer" main.py

# %%
# !python main_v7.py
